# %% [markdown]
# <a href="https://colab.research.google.com/github/anthonyaraujo8/2-TRABALHO-DE-AM/blob/main/Processamento.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Importando bibliotecas necessárias
import pandas as pd
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# Carregando o Iris Dataset
iris = datasets.load_iris()
X = iris.data
y = iris.target

# Dividindo o conjunto de dados em treinamento e teste
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Normalizando os dados
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# K-Nearest Neighbors
knn = KNeighborsClassifier(n_neighbors=3)
knn.fit(X_train, y_train)
y_pred_knn = knn.predict(X_test)

# Support Vector Machine
svm = SVC(kernel='linear')
svm.fit(X_train, y_train)
y_pred_svm = svm.predict(X_test)

# Random Forest
rf = RandomForestClassifier(n_estimators=100)
rf.fit(X_train, y_train)
y_pred_rf = rf.predict(X_test)

# Regressão Logística
log_reg = LogisticRegression()
log_reg.fit(X_train, y_train)
y_pred_log_reg = log_reg.predict(X_test)

# Avaliando os resultados
def evaluate_model(y_true, y_pred):
    accuracy = accuracy_score(y_true, y_pred)
    precision = precision_score(y_true, y_pred, average='weighted')
    recall = recall_score(y_true, y_pred, average='weighted')
    f1 = f1_score(y_true, y_pred, average='weighted')
    return accuracy, precision, recall, f1

# Resultados
results = {
    "KNN": evaluate_model(y_test, y_pred_knn),
    "SVM": evaluate_model(y_test, y_pred_svm),
    "Random Forest": evaluate_model(y_test, y_pred_rf),
    "Regressão Logística": evaluate_model(y_test, y_pred_log_reg)
}

# Exibindo os resultados
for model, metrics in results.items():
    print(f"{model} - Acurácia: {metrics[0]:.2f}, Precisão: {metrics[1]:.2f}, Recall: {metrics[2]:.2f}, F1-score: {metrics[3]:.2f}")
# Out:
# KNN - Acurácia: 1.00, Precisão: 1.00, Recall: 1.00, F1-score: 1.00
# SVM - Acurácia: 0.98, Precisão: 0.98, Recall: 0.98, F1-score: 0.98
# Random Forest - Acurácia: 1.00, Precisão: 1.00, Recall: 1.00, F1-score: 1.00
# Regressão Logística - Acurácia: 1.00, Precisão: 1.00, Recall: 1.00, F1-score: 1.00

# %%
   import matplotlib.pyplot as plt
   import seaborn as sns
   from sklearn import datasets
   import pandas as pd

   # Carregando o Iris Dataset
   iris = datasets.load_iris()
   iris_df = pd.DataFrame(data=iris.data, columns=iris.feature_names)
   iris_df['species'] = iris.target

   # Mapeando os números das classes para os nomes das espécies
   iris_df['species'] = iris_df['species'].map({0: 'Iris-setosa', 1: 'Iris-versicolor', 2: 'Iris-virginica'})

   # Criando o gráfico de dispersão
   plt.figure(figsize=(10, 6))
   sns.scatterplot(data=iris_df, x='sepal length (cm)', y='sepal width (cm)', hue='species', palette='Set1')
   plt.title('Visualização do Iris Dataset')
   plt.xlabel('Comprimento da Sépala (cm)')
   plt.ylabel('Largura da Sépala (cm)')
   plt.legend(title='Espécie')
   plt.grid()
   plt.savefig('iris_dataset_visualization.png')  # Salva a figura como PNG
   plt.show()

# %%
   import matplotlib.pyplot as plt
   import numpy as np

   # Dados de desempenho dos algoritmos
   algoritmos = ['KNN', 'SVM', 'Random Forest', 'Regressão Logística']
   acuracia = [100, 98, 100, 100]
   precisao = [100, 98, 100, 100]
   recall = [100, 98, 100, 100]
   f1_score = [100, 98, 100, 100]

   # Configurando o gráfico
   x = np.arange(len(algoritmos))  # o local dos rótulos
   largura = 0.2  # a largura das barras

   fig, ax = plt.subplots(figsize=(10, 6))
   bars1 = ax.bar(x - largura*1.5, acuracia, largura, label='Acurácia')
   bars2 = ax.bar(x - largura/2, precisao, largura, label='Precisão')
   bars3 = ax.bar(x + largura/2, recall, largura, label='Recall')
   bars4 = ax.bar(x + largura*1.5, f1_score, largura, label='F1-score')

   # Adicionando algumas anotações
   ax.set_ylabel('Porcentagem (%)')
   ax.set_title('Comparação de Desempenho dos Algoritmos')
   ax.set_xticks(x)
   ax.set_xticklabels(algoritmos)
   ax.legend()

   # Exibindo o gráfico
   plt.grid()
   plt.savefig('comparacao_desempenho_algoritmos.png')  # Salva a figura como PNG
   plt.show()

# %% [markdown]
# # Nova seção
